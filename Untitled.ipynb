# %%
import csv
import glob
print(glob.glob("*.csv"))
import logging
logging.basicConfig()

from rdflib import Graph,Namespace,URIRef, Literal
from rdflib.namespace import RDF, FOAF, OWL, RDFS, DCTERMS

n = Namespace("http://gemeenteraad.org/")
dbp=Namespace("http://dbpedia.org/resource/")
g = Graph()
g.add((n.CBScode,RDF.type, RDF.Property))
g.add((n.CBScode,DCTERMS.description,Literal("CBS code")))
g.add((n.valid_vote,RDF.type,RDF.Property))
g.add((n.valid_vote,DCTERMS.description,Literal("Number of valid votes")))
g.add((n.invalid_vote,RDF.type,RDF.Property))
g.add((n.invalid_vote,DCTERMS.description,Literal("Number of Invalid votes")))
g.add((n.blank_vote,RDF.type,RDF.Property))
g.add((n.blank_vote,DCTERMS.description,Literal("Number of blank votes")))
g.add((n.per_blank,RDF.type,RDF.Property))
g.add((n.per_blank,DCTERMS.description,Literal("Percentage of blank votes")))
g.add((n.pp_allowed,RDF.type,RDF.Property))
g.add((n.pp_allowed,DCTERMS.description,Literal("Number of people allowed to vote")))
g.add((n.vote_num,RDF.type,RDF.Property))
g.add((n.vote_num,DCTERMS.description,Literal("Number of people that actually voted")))
g.add((n.vote_percent,RDF.type,RDF.Property))
g.add((n.vote_percent,DCTERMS.description,Literal("Percentage of people that actually voted")))

#KVP
g.add((n.KVP,RDF.type,RDF.Property))
g.add((n.KVP,DCTERMS.description,Literal("Catholic People's Party")))
g.add((n.KVP,OWL.sameAs,dbp["Catholic_People's_Party"]))
#VVD
g.add((n.VVD,RDF.type,RDF.Property))
g.add((n.VVD,DCTERMS.description,Literal("Liberals (VVD)")))
g.add((n.VVD,OWL.sameAs,dbp['People%27s_Party_for_Freedom_and_Democracy']))
#CPN
g.add((n.CPN,RDF.type,RDF.Property))
g.add((n.CPN,DCTERMS.description,Literal("Liberals (VVD)")))
g.add((n.CPN,OWL.sameAs,dbp['Communist_Party_of_the_Netherlands']))
#D66
g.add((n.D66,RDF.type,RDF.Property))
g.add((n.D66,DCTERMS.description,Literal("Democrats (D66)")))
g.add((n.D66,OWL.sameAs,dbp['Democrats_66']))
#PvdA
g.add((n.PvdA,RDF.type,RDF.Property))
g.add((n.PvdA,DCTERMS.description,Literal("Labor party (PvdA)")))
g.add((n.PvdA,OWL.sameAs,dbp['Labour_Party_(Netherlands)']))
#ARP
g.add((n.ARP,RDF.type,RDF.Property))
g.add((n.ARP,DCTERMS.description,Literal("Anti-Revolutionary Party")))
g.add((n.ARP,OWL.sameAs,dbp['Anti-Revolutionary_Party']))
#CHU
g.add((n.CHU,RDF.type,RDF.Property))
g.add((n.CHU,DCTERMS.description,Literal("Christelijk-Historische Unie")))
g.add((n.CHU,OWL.sameAs,dbp['Christian_Historical_Union']))
#PvdV
g.add((n.PvdV,RDF.type,RDF.Property))
g.add((n.PvdV,DCTERMS.description,Literal("Freedom Party (Netherlands)")))
g.add((n.PvdV,OWL.sameAs,dbp['Freedom_Party_(Netherlands)']))
#SGP
g.add((n.SGP,RDF.type,RDF.Property))
g.add((n.SGP,DCTERMS.description,Literal("Reformed Political Party")))
g.add((n.SGP,OWL.sameAs,dbp['Reformed_Political_Party']))
#RK
g.add((n.RK,RDF.type,RDF.Property))
#PCG
g.add((n.PCG,RDF.type,RDF.Property))
g.add((n.PCG,DCTERMS.description,Literal("Protestant-Christelijke Groepering")))
#KNP
g.add((n.KNP,RDF.type,RDF.Property))
g.add((n.KNP,DCTERMS.description,Literal("Catholic National Party")))
g.add((n.KNP,OWL.sameAs,dbp['Catholic_National_Party']))
#GG
g.add((n.GG,RDF.type,RDF.Property))
#GPV
g.add((n.GPV,RDF.type,RDF.Property))
g.add((n.GPV,DCTERMS.description,Literal("Reformed Political League")))
g.add((n.GPV,OWL.sameAs,dbp['Reformed_Political_League']))
#PC
g.add((n.PC,RDF.type,RDF.Property))
#PSP
g.add((n.PSP,RDF.type,RDF.Property))
g.add((n.PSP,DCTERMS.description,Literal("Pacifist Socialist Party")))
g.add((n.PSP,OWL.sameAs,dbp['Pacifist_Socialist_Party']))
#BP
g.add((n.BP,RDF.type,RDF.Property))
g.add((n.BP,DCTERMS.description,Literal("Farmers' Party (Netherlands)")))
g.add((n.BP,OWL.sameAs,dbp['Farmers%27_Party_(Netherlands)']))
#CDA
g.add((n.CDA,RDF.type,RDF.Property))
g.add((n.CDA,DCTERMS.description,Literal("Christian Democratic Appeal")))
g.add((n.CDA,OWL.sameAs,dbp['Christian_Democratic_Appeal']))
#PAK
g.add((n.PAK,RDF.type,RDF.Property))
g.add((n.PAK,DCTERMS.description,Literal("Progressieve samenwerking in Nederland in de jaren 1970")))
g.add((n.PAK,OWL.sameAs,dbp['Progressieve_samenwerking_in_Nederland_in_de_jaren_1970']))
#PPR
g.add((n.PPR,RDF.type,RDF.Property))
g.add((n.PPR,DCTERMS.description,Literal("Political Party of Radicals")))
g.add((n.PPR,OWL.sameAs,dbp['Political_Party_of_Radicals']))
#DS70
g.add((n.DS70,RDF.type,RDF.Property))
g.add((n.DS70,DCTERMS.description,Literal("Democratic Socialists '70")))
g.add((n.DS70,OWL.sameAs,dbp['Democratic_Socialists_%2770']))
#DS70
g.add((n.DS70,RDF.type,RDF.Property))
g.add((n.DS70,DCTERMS.description,Literal("Democratic Socialists '70")))
g.add((n.DS70,OWL.sameAs,dbp['Democratic_Socialists_%2770']))
#RPF
g.add((n.RPF,RDF.type,RDF.Property))
g.add((n.RPF,DCTERMS.description,Literal("Reformatory Political Federation")))
g.add((n.RPF,OWL.sameAs,dbp['Reformatory_Political_Federation']))
#CD
g.add((n.CD,RDF.type,RDF.Property))
g.add((n.CD,DCTERMS.description,Literal("Centre Democrats (Netherlands)")))
g.add((n.CD,OWL.sameAs,dbp['Centre_Democrats_(Netherlands)']))
#SP
g.add((n.SP,RDF.type,RDF.Property))
g.add((n.SP,DCTERMS.description,Literal("Socialist Party (Netherlands)")))
g.add((n.SP,OWL.sameAs,dbp['Socialist_Party_(Netherlands)']))
#LOG
g.add((n.LOG,RDF.type,RDF.Property))
#GL
g.add((n.GL,RDF.type,RDF.Property))
g.add((n.GL,DCTERMS.description,Literal("GroenLinks")))
g.add((n.GL,OWL.sameAs,dbp['GroenLinks']))
#LCG
g.add((n.LCG,RDF.type,RDF.Property))
#LPG
g.add((n.LPG,RDF.type,RDF.Property))
#CP86
g.add((n.CP86,RDF.type,RDF.Property))
g.add((n.CP86,DCTERMS.description,Literal("Centre Party '86")))
g.add((n.CP86,OWL.sameAs,dbp['Centre_Party_%2786']))
#CU
g.add((n.CU,RDF.type,RDF.Property))
g.add((n.CU,DCTERMS.description,Literal("Christian Union (Netherlands)")))
g.add((n.CU,OWL.sameAs,dbp['Christian_Union_(Netherlands)']))

                            
for path in glob.glob("*.csv"):
#     print path
    paths=path.split("-")
#     print paths
    year=paths[2].replace(".csv","")
    check=paths[1]
    with open(path) as csvfile:
#         year=path.replace("gemeenteraad-","")
#         year=year.replace(".csv","")
#         print year
        if check=="1":
            csvreader = csv.DictReader(csvfile,delimiter=';')
            headers = csvreader.next()
            for row in csvreader:
                name='Naam'
                temp=row[name].replace(" ","_")
                locals()['row[name]']=URIRef("http://gemeenteraad.org/"+temp)
                g.add((locals()['row[name]'],RDF.type,OWL.municipality))
                g.add((locals()['row[name]'],RDFS.label, Literal(temp)))
                for r in row:
                    if row[r]!="":
                        if r=='Amsterdamse code':
                            locals()['row[r]']=URIRef("http://gemeenteraad.org/"+row[r])
                            g.add((locals()['row[r]'], RDF.type, OWL.amsterdamCode))
                            g.add((locals()['row[r]'], RDFS.label, Literal(row[r])))
                        elif r=='CBS code':
                            locals()['row[r]']=URIRef("http://gemeenteraad.org/"+row[r])
                            g.add((locals()['row[r]'],RDFS.label,Literal(row['CBS code'])))
                            g.add((locals()['row[name]'],n.CBScode,locals()['row[r]']))
                        elif r=='# geldige stemmen':
                            if (n['valid_vote'+'('+year+')'],DCTERMS.description,Literal("Number of valid votes in "+year)) in g:
                                g.add((locals()['row[name]'],n['valid_vote'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['valid_vote'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['valid_vote'+'('+year+')'],DCTERMS.description,Literal("Number of valid votes in "+year)))
                                g.add((locals()['row[name]'],n['valid_vote'+'('+year+')'],Literal(row[r])))
                        elif r=='# ongeldige stemmen':
                            if (n['invalid_vote'+'('+year+')'],DCTERMS.description,Literal("Number of invalid votes in "+year)) in g:
                                g.add((locals()['row[name]'],n['invalid_vote'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['invalid_vote'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['invalid_vote'+'('+year+')'],DCTERMS.description,Literal("Number of invalid votes in "+year)))
                                g.add((locals()['row[name]'],n['invalid_vote'+'('+year+')'],Literal(row[r])))
                        elif r=='# ongeldige':
                            if (n['invalid_vote'+'('+year+')'],DCTERMS.description,Literal("Number of invalid votes in "+year)) in g:
                                g.add((locals()['row[name]'],n['invalid_vote'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['invalid_vote'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['invalid_vote'+'('+year+')'],DCTERMS.description,Literal("Number of invalid votes in "+year)))
                                g.add((locals()['row[name]'],n['invalid_vote'+'('+year+')'],Literal(row[r])))
                        elif r=='# blanco stemmen':
                            if (n['blank_vote'+'('+year+')'],DCTERMS.description,Literal("Number of blank votes in "+year)) in g:
                                g.add((locals()['row[name]'],n['blank_vote'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['blank_vote'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['blank_vote'+'('+year+')'],DCTERMS.description,Literal("Number of blank votes in "+year)))
                                g.add((locals()['row[name]'],n['blank_vote'+'('+year+')'],Literal(row[r])))
                        elif r=='# ongeldige/blanco stemmen':
                            if (n['invalid_vote'+'('+year+')'],DCTERMS.description,Literal("Number of invalid votes in "+year)) in g:
                                g.add((locals()['row[name]'],n['invalid_vote'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['invalid_vote'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['invalid_vote'+'('+year+')'],DCTERMS.description,Literal("Number of invalid votes in "+year)))
                            if (n['blank_vote'+'('+year+')'],DCTERMS.description,Literal("Number of blank votes in "+year)) in g:
                                g.add((locals()['row[name]'],n['blank_vote'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['blank_vote'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['blank_vote'+'('+year+')'],DCTERMS.description,Literal("Number of blank votes in "+year)))
                                g.add((locals()['row[name]'],n['blank_vote'+'('+year+')'],Literal(row[r])))
                        elif r=='Percentage ongeldige/blanco stemmen':
                            if (n['percent_invalid_blank'+'('+year+')'],DCTERMS.description,Literal("Percentage of invalid and blank votes in "+year)) in g:
                                g.add((locals()['row[name]'],n['percent_invalid_blank'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['percent_invalid_blank'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['percent_invalid_blank'+'('+year+')'],DCTERMS.description,Literal("Percentage of invalid and blank votes in "+year)))
                                g.add((locals()['row[name]'],n['percent_invalid_blank'+'('+year+')'],Literal(row[r])))
                        elif r=='Percentage ongeldige stemmen':
                            if (n['percent_invalid'+'('+year+')'],DCTERMS.description,Literal("Percentage of invalid votes in "+year)) in g:
                                g.add((locals()['row[name]'],n['percent_invalid'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['percent_invalid'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['percent_invalid'+'('+year+')'],DCTERMS.description,Literal("Percentage of invalid votes in "+year)))
                                g.add((locals()['row[name]'],n['percent_invalid'+'('+year+')'],Literal(row[r])))
                        elif r=='Percentage blanco stemmen':
                            if (n['percent_blank'+'('+year+')'],DCTERMS.description,Literal("Percentage of blank votes in "+year)) in g:
                                g.add((locals()['row[name]'],n['percent_blank'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['percent_blank'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['percent_blank'+'('+year+')'],DCTERMS.description,Literal("Percentage of blank votes in "+year)))
                                g.add((locals()['row[name]'],n['percent_blank'+'('+year+')'],Literal(row[r])))
                        elif r=='# kiesgerechtigden':
                            if (n['voters_number'+'('+year+')'],DCTERMS.description,Literal("Number of voters in "+year)) in g:
                                g.add((locals()['row[name]'],n['voters_number'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['voters_number'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['voters_number'+'('+year+')'],DCTERMS.description,Literal("Number of voters in "+year)))
                                g.add((locals()['row[name]'],n['voters_number'+'('+year+')'],Literal(row[r])))
                        elif r=='Opkomst':
                            if (n['vote_number'+'('+year+')'],DCTERMS.description,Literal("Number of vote in "+year)) in g:
                                g.add((locals()['row[name]'],n['vote_number'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['vote_number'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['vote_number'+'('+year+')'],DCTERMS.description,Literal("Number of vote in "+year)))
                                g.add((locals()['row[name]'],n['vote_number'+'('+year+')'],Literal(row[r])))
                        elif r=='Opkomstpercentage':
                            if (n['percent_vote'+'('+year+')'],DCTERMS.description,Literal("Percentage of vote in "+year)) in g:
                                g.add((locals()['row[name]'],n['percent_vote'+'('+year+')'],Literal(row[r])))
                            else:
                                g.add((n['percent_vote'+'('+year+')'],RDF.type,RDF.Property))
                                g.add((n['percent_vote'+'('+year+')'],DCTERMS.description,Literal("Percentage of vote in "+year)))
                                g.add((locals()['row[name]'],n['percent_vote'+'('+year+')'],Literal(row[r])))
                        elif r!='Naam':
                            g.add((locals()['row[name]'],n[r.replace(" ","_")+'('+year+')'],Literal(row[r])))
                        
#         if check=='1':
#             csvreader = csv.DictReader(csvfile,delimiter=';')
#             headers = csvreader.next()
#             for row in csvreader:
#                 var = row['Amsterdamse code']
#                 amco='var'
#                 var1=row['Naam'].replace(" ","_")
#                 name='var1'
#                 var2=row['CBS code']
#                 cbs='var2'
#                 locals()[amco]=URIRef("http://gemeenteraad.org/"+var)
#                 locals()[name]=URIRef("http://gemeenteraad.org/"+var1)
#                 locals()[cbs]=n[var2]
#                 g.add((locals()[amco], RDF.type, OWL.amsterdamCode))
#                 g.add((locals()[amco],RDFS.label,Literal(row['Amsterdamse code'])))
#                 g.add((locals()[name],RDF.type,OWL.municipality))
#                 g.add((locals()[name],RDFS.label,Literal(row['Naam'])))
#                 g.add((locals()[name],n.hasCBScode,locals()[cbs]))
#                 g.add((locals()[name],n.valid_vote,Literal(row['# geldige stemmen']+"("+year+")")))
#                 g.add((locals()[name],n.invalid_vote,Literal(row['# ongeldige/blanco stemmen']+"("+year+")")))
#                 g.add((locals()[name],n.blank_vote,Literal(row['Number of blank votes']+"("+year+")")))
#                 g.add((locals()[name],n.per_blank,Literal(row['Percentage ongeldige/blanco stemmen']+"("+year+")")))
#                 g.add((locals()[name],n.pp_allowed,Literal(row['Number of people allowed to vote']+"("+year+")")))
#                 g.add((locals()[name],n.vote_num,Literal(row['Number of people that actually voted']+"("+year+")")))
#                 g.add((locals()[name],n.vote_percent,Literal(row['Percentage of people that actually voted']+"("+year+")")))
#                 g.add((locals()[name],n.local_vote,Literal(row['Local parties']+"("+year+")")))
#                 g.add((locals()[name],n.CDA,Literal(row['Christian Democrats (CDA)']+"("+year+")")))
#                 g.add((locals()[name],n.VVD,Literal(row['Liberals (VVD)']+"("+year+")")))
#                 g.add((locals()[name],n.D66,Literal(row['Democrats (D66)']+"("+year+")")))
#                 g.add((locals()[name],n.PvdA,Literal(row['Labor party (PvdA)']+"("+year+")")))
#                 g.add((locals()[name],n.SP,Literal(row['Socialist party (SP)']+"("+year+")")))
#                 g.add((locals()[name],n.GROENLINKS,Literal(row['Socialist/ecology party (GROENLINKS)']+"("+year+")")))
#                 g.add((locals()[name],n.ChristenUnie,Literal(row['Christian party (ChristenUnie)']+"("+year+")")))
#                 g.add((locals()[cbs],RDFS.label,Literal(row['CBS code'])))
g.serialize(destination='output.ttl', format='turtle')
# Out:
# ['gemeenteraad-1-1962.csv', 'gemeenteraad-1-1982.csv', 'gemeenteraad-2-1994.csv', 'gemeenteraad-2-1958.csv', 'gemeenteraad-1-1998.csv', 'gemeenteraad-2-2010.csv.csv', 'gemeenteraad-1-1958.csv', 'gemeenteraad-2-1978.csv', 'gemeenteraad-2-1998.csv', 'gemeenteraad-1-1974.csv', 'gemeenteraad-1-1990.csv', 'gemeenteraad-1-2002.csv', 'gemeenteraad-1-1946.csv', 'gemeenteraad-1-2010.csv', 'gemeenteraad-2-2002.csv', 'gemeenteraad-2-1966.csv', 'gemeenteraad-2-2014.csv.csv', 'gemeenteraad-2-1986.csv', 'gemeenteraad-2-1953.csv', 'gemeenteraad-1-1994.csv', 'gemeenteraad-2-1949.csv', 'gemeenteraad-2-2006.csv.csv', 'gemeenteraad-2-1946.csv', 'gemeenteraad-1-1953.csv', 'gemeenteraad-1-2006.csv', 'gemeenteraad-1-1949.csv', 'gemeenteraad-1-1986.csv', 'gemeenteraad-1-1966.csv', 'gemeenteraad-1-1978.csv', 'gemeenteraad-1-2014.csv', 'gemeenteraad-2-1974.csv', 'gemeenteraad-2-1982.csv', 'gemeenteraad-2-1990.csv', 'gemeenteraad-2-1962.csv']
